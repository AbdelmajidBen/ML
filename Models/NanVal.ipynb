# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris, load_digits, load_wine

# %%
col_names=["c1","c2","c3","c4","class"]

# %%
df=pd.read_csv('/Users/mac/Desktop/Programming_Stuff/Machine Learning/Datasets/titanic.csv')

# %%
df.isnull().sum()
# Out:
# Passengerid    0
# Age            0
# Fare           0
# Sex            0
# sibsp          0
# zero           0
# zero.1         0
# zero.2         0
# zero.3         0
# zero.4         0
# zero.5         0
# zero.6         0
# Parch          0
# zero.7         0
# zero.8         0
# zero.9         0
# zero.10        0
# zero.11        0
# zero.12        0
# zero.13        0
# zero.14        0
# Pclass         0
# zero.15        0
# zero.16        0
# Embarked       2
# zero.17        0
# zero.18        0
# 2urvived       0
# dtype: int64

# %%
c = 0
for i in df.columns:
    for j in range(len(df)):
        if pd.isnull(df[i].iloc[j]):
            c += 1   
            print("The column", i, "has a missing value in the position", j)
print("The total number of missing values is", c)
# Out:
# The column Embarked has a missing value in the position 61
# The column Embarked has a missing value in the position 829
# The total number of missing values is 2

# %%
names=list(df.columns)

# %%
df[names]
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
df['Age']= df['Age'].replace(np.nan,df['Age'].median())

# %%
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df, cmap='viridis')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.show()

# %%
for col in df.columns:
    if df[col].nunique() == 1:
        df.drop(col, axis=1, inplace=True)

# %% [markdown]
# # Outlires

# %%
test_data= [173, 179, 180,184,187,190,195,201,204,215,272]

# %%
s=0
for i in test_data:
    s=s+i
print(' the sum is ',s)
# Out:
#  the sum is  2180

# %%
# Out:
# 173

# %%
sum_xi=test_data[0]
print(sum_x)
# Out:
# 1090.0

# %%
sum_liste=[]
sum_xi=0
for i in range(len(test_data)):
    sum_xi=sum_xi+test_data[i]
    sum_liste.append(sum_xi)

print(sum_liste)
# Out:
# [173, 352, 532, 716, 903, 1093, 1288, 1489, 1693, 1908, 2180]

# %%
c = 0
VQ2 = s / 2 
VQ3= 0.75 *s
VQ1 = s / 4
print(test_data)

for i in sum_liste:
    if i >= VQ2:
        break
    else:
        c += 1

print('The mediane value is', test_data[c])
# Out:
# [173, 179, 180, 184, 187, 190, 195, 201, 204, 215, 272]
# The mediane value is 190

# %%
c=0
for i in sum_liste:
    if i >= VQ1:
        break
    else:
        c += 1

print('The 1ST quartile value is', test_data[c])
# Out:
# The 1ST quartile value is 184

# %%
c=0

for i in sum_liste:
    if i >= VQ3:
        break
    else:
        c += 1

print('The 3rd quartile value is', test_data[c])
# Out:
# The 3rd quartile value is 204

# %% [markdown]
# # BoxPlot testing on iris

# %%
import pandas as pd
import numpy as np

# %%
url ="/Users/mac/Desktop/Programming_Stuff/Machine Learning/Datasets/Iris.csv"
df =pd.read_csv(url)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
