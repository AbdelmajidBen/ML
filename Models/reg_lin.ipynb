# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler,Normalizer
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('/Users/mac/Desktop/Programming_Stuff/Machine Learning/Datasets/train.csv')
df2=pd.read_csv('/Users/mac/Desktop/Programming_Stuff/Machine Learning/Datasets/test.csv')

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.describe()
# Out:
#                  x           y
# count  1000.000000  999.000000
# mean     53.771157   50.319804
# std     113.747929   29.089111
# min       0.000000   -3.839981
# 25%      25.000000   25.185430
# 50%      50.000000   49.926397
# 75%      75.000000   74.475252
# max    3530.157369  108.871618

# %%
df.isna().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
# filing the missing value with the mode of the column 
df=df.fillna(df.mode().iloc[0])

# %%
df.isna().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
plt.scatter(df['x'], df['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('plotting with matplotlib')
plt.title('Scatter plot of y vs x')
plt.show()

# %%
import seaborn as sns

# Assuming df is your DataFrame
sns.scatterplot(x='x', y='y', data=df,color='red')
plt.show()

# %%
std=StandardScaler()
df1=std.fit_transform(df)

# %%
df1
# Out:
# array([[-0.26186019, -0.98645876],
#        [-0.03317022, -0.09622618],
#        [-0.3410221 , -1.13523028],
#        ...,
#        [ 0.01080861,  0.13139618],
#        [ 0.07237899,  0.44765907],
#        [-0.05955753,  0.07536222]])

# %%
X=df['x']
Y=df['y']

# %%
X
# Out:
# 0      24.0
# 1      50.0
# 2      15.0
# 3      38.0
# 4      87.0
#        ...
# 995    71.0
# 996    46.0
# 997    55.0
# 998    62.0
# 999    47.0
# Name: x, Length: 1000, dtype: float64

# %%
import pandas as pd
import numpy as np

# Assuming your NumPy array is called 'array'
df3 = pd.DataFrame(df1)

# Display the DataFrame
print(df3)
# Out:
#             0         1
# 0   -0.261860 -0.986459
# 1   -0.033170 -0.096226
# 2   -0.341022 -1.135230
# 3   -0.138719 -0.469910
# 4    0.292273  1.271826
# ..        ...       ...
# 995  0.151541  0.627963
# 996 -0.068353 -0.100678
# 997  0.010809  0.131396
# 998  0.072379  0.447659
# 999 -0.059558  0.075362
#
# [1000 rows x 2 columns]

# %%
X=df3.iloc[:,0].values

# %%
Y=df3.iloc[:,1].values

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model=LinearRegression()

# %%
model.fit(xtrain.reshape(-1,1),ytrain)
# Out:
# LinearRegression()

# %%
yh=model.predict(xtest.reshape(-1,1))

# %%
r2=r2_score(ytest,yh)
print(r2)
# Out:
# 0.03236955875240621
