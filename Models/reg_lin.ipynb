# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler,Normalizer,
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('/Users/mac/Desktop/Programming_Stuff/Machine Learning/Datasets/train.csv')
df2=pd.read_csv('/Users/mac/Desktop/Programming_Stuff/Machine Learning/Datasets/test.csv')

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.describe()
# Out:
#                  x           y
# count  1000.000000  999.000000
# mean     53.771157   50.319804
# std     113.747929   29.089111
# min       0.000000   -3.839981
# 25%      25.000000   25.185430
# 50%      50.000000   49.926397
# 75%      75.000000   74.475252
# max    3530.157369  108.871618

# %%
df.isna().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
# filing the missing value with the mode of the column 
df=df.fillna(df.mode().iloc[0])

# %%
df.isna().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
plt.scatter(df['x'], df['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of y vs x')
plt.show()

# %%
import seaborn as sns

# Assuming df is your DataFrame
sns.scatterplot(x='x', y='y', data=df,color='red')
plt.show()

# %%
std=StandardScaler()
df1=std.fit_transform(df)

# %%
df1
# Out:
# array([[-0.26186019, -0.98856976],
#        [-0.03317022, -0.09722528],
#        [-0.3410221 , -1.13752709],
#        ...,
#        [ 0.01080861,  0.13068137],
#        [ 0.07237899,  0.44733927],
#        [-0.05955753,  0.07457742]])

# %%
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 995  71.0  68.545888
# 996  46.0  47.334876
# 997  55.0  54.090637
# 998  62.0  63.297171
# 999  47.0  52.459467
#
# [1000 rows x 2 columns]
